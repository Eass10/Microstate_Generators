# %%
import utils as u

# Base URL of the LEMON dataset
base_url = "https://ftp.gwdg.de/pub/misc/MPI-Leipzig_Mind-Brain-Body-LEMON/EEG_MPILMBB_LEMON/EEG_Raw_BIDS_ID/"

# Destination directory to save the files
destination_directory = "DATA_FOLDER"

# Download files from the base URL recursively
u.download_files_from_url(base_url, destination_directory)

print("Download completed. Files are located in:", destination_directory)
# Out:
# El directorio 'DATA_FOLDER\sub-010002/' ya existe. Saltando descarga.
# El directorio 'DATA_FOLDER\sub-010003/' ya existe. Saltando descarga.
# El directorio 'DATA_FOLDER\sub-010004/' ya existe. Saltando descarga.
# El directorio 'DATA_FOLDER\sub-010005/' ya existe. Saltando descarga.
# El directorio 'DATA_FOLDER\sub-010006/' ya existe. Saltando descarga.
# El directorio 'DATA_FOLDER\sub-010007/' ya existe. Saltando descarga.
# El directorio 'DATA_FOLDER\sub-010010/' ya existe. Saltando descarga.
# El directorio 'DATA_FOLDER\sub-010012/' ya existe. Saltando descarga.
# El directorio 'DATA_FOLDER\sub-010015/' ya existe. Saltando descarga.
# El directorio 'DATA_FOLDER\sub-010016/' ya existe. Saltando descarga.
# El directorio 'DATA_FOLDER\sub-010017/' ya existe. Saltando descarga.
# El directorio 'DATA_FOLDER\sub-010019/' ya existe. Saltando descarga.
# El directorio 'DATA_FOLDER\sub-010020/' ya existe. Saltando descarga.
# ...
