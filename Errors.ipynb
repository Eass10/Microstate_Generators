# %%
import utils as u

# Example usage:
patient_id = '010150'
u.move_error_files(patient_id)
# Out:
# Moved sub-010150_A-B.csv to H:\CSIC\ERRORS\segment_1
# Moved sub-010150_A-C.csv to H:\CSIC\ERRORS\segment_1
# Moved sub-010150_A-D.csv to H:\CSIC\ERRORS\segment_1
# Moved sub-010150_B-A.csv to H:\CSIC\ERRORS\segment_1
# Moved sub-010150_B-C.csv to H:\CSIC\ERRORS\segment_1
# Moved sub-010150_B-D.csv to H:\CSIC\ERRORS\segment_1
# Moved sub-010150_C-A.csv to H:\CSIC\ERRORS\segment_1
# Moved sub-010150_C-B.csv to H:\CSIC\ERRORS\segment_1
# Moved sub-010150_C-D.csv to H:\CSIC\ERRORS\segment_1
# Moved sub-010150_D-A.csv to H:\CSIC\ERRORS\segment_1
# Moved sub-010150_D-B.csv to H:\CSIC\ERRORS\segment_1
# Moved sub-010150_D-C.csv to H:\CSIC\ERRORS\segment_1
# Moved sub-010150_A-B.csv to H:\CSIC\ERRORS\segment_2
# Moved sub-010150_A-C.csv to H:\CSIC\ERRORS\segment_2
# Moved sub-010150_A-D.csv to H:\CSIC\ERRORS\segment_2
# Moved sub-010150_B-A.csv to H:\CSIC\ERRORS\segment_2
# Moved sub-010150_B-C.csv to H:\CSIC\ERRORS\segment_2
# Moved sub-010150_B-D.csv to H:\CSIC\ERRORS\segment_2
# Moved sub-010150_C-A.csv to H:\CSIC\ERRORS\segment_2
# Moved sub-010150_C-B.csv to H:\CSIC\ERRORS\segment_2
# Moved sub-010150_C-D.csv to H:\CSIC\ERRORS\segment_2
# Moved sub-010150_D-A.csv to H:\CSIC\ERRORS\segment_2
# Moved sub-010150_D-B.csv to H:\CSIC\ERRORS\segment_2
# Moved sub-010150_D-C.csv to H:\CSIC\ERRORS\segment_2
# Moved sub-010150_A-B.csv to H:\CSIC\ERRORS\segment_3
# Moved sub-010150_A-C.csv to H:\CSIC\ERRORS\segment_3
# Moved sub-010150_A-D.csv to H:\CSIC\ERRORS\segment_3
# Moved sub-010150_B-A.csv to H:\CSIC\ERRORS\segment_3
# Moved sub-010150_B-C.csv to H:\CSIC\ERRORS\segment_3
# Moved sub-010150_B-D.csv to H:\CSIC\ERRORS\segment_3
# Moved sub-010150_C-A.csv to H:\CSIC\ERRORS\segment_3
# Moved sub-010150_C-B.csv to H:\CSIC\ERRORS\segment_3
# Moved sub-010150_C-D.csv to H:\CSIC\ERRORS\segment_3
# Moved sub-010150_D-A.csv to H:\CSIC\ERRORS\segment_3
# Moved sub-010150_D-B.csv to H:\CSIC\ERRORS\segment_3
# Moved sub-010150_D-C.csv to H:\CSIC\ERRORS\segment_3
# Moved sub-010150_A-B.csv to H:\CSIC\ERRORS\segment_4
# Moved sub-010150_A-C.csv to H:\CSIC\ERRORS\segment_4
# Moved sub-010150_A-D.csv to H:\CSIC\ERRORS\segment_4
# Moved sub-010150_B-A.csv to H:\CSIC\ERRORS\segment_4
# Moved sub-010150_B-C.csv to H:\CSIC\ERRORS\segment_4
# Moved sub-010150_B-D.csv to H:\CSIC\ERRORS\segment_4
# Moved sub-010150_C-A.csv to H:\CSIC\ERRORS\segment_4
# Moved sub-010150_C-B.csv to H:\CSIC\ERRORS\segment_4
# Moved sub-010150_C-D.csv to H:\CSIC\ERRORS\segment_4
# Moved sub-010150_D-A.csv to H:\CSIC\ERRORS\segment_4
# Moved sub-010150_D-B.csv to H:\CSIC\ERRORS\segment_4
# Moved sub-010150_D-C.csv to H:\CSIC\ERRORS\segment_4
# Moved sub-010150_A-B.csv to H:\CSIC\ERRORS\segment_5
# Moved sub-010150_A-C.csv to H:\CSIC\ERRORS\segment_5
# Moved sub-010150_A-D.csv to H:\CSIC\ERRORS\segment_5
# Moved sub-010150_B-A.csv to H:\CSIC\ERRORS\segment_5
# Moved sub-010150_B-C.csv to H:\CSIC\ERRORS\segment_5
# Moved sub-010150_B-D.csv to H:\CSIC\ERRORS\segment_5
# Moved sub-010150_C-A.csv to H:\CSIC\ERRORS\segment_5
# Moved sub-010150_C-B.csv to H:\CSIC\ERRORS\segment_5
# Moved sub-010150_C-D.csv to H:\CSIC\ERRORS\segment_5
# Moved sub-010150_D-A.csv to H:\CSIC\ERRORS\segment_5
# Moved sub-010150_D-B.csv to H:\CSIC\ERRORS\segment_5
# Moved sub-010150_D-C.csv to H:\CSIC\ERRORS\segment_5
# Moved sub-010150_A-B.csv to H:\CSIC\ERRORS\segment_6
# Moved sub-010150_A-C.csv to H:\CSIC\ERRORS\segment_6
# Moved sub-010150_A-D.csv to H:\CSIC\ERRORS\segment_6
# Moved sub-010150_B-A.csv to H:\CSIC\ERRORS\segment_6
# Moved sub-010150_B-C.csv to H:\CSIC\ERRORS\segment_6
# Moved sub-010150_B-D.csv to H:\CSIC\ERRORS\segment_6
# Moved sub-010150_C-A.csv to H:\CSIC\ERRORS\segment_6
# Moved sub-010150_C-B.csv to H:\CSIC\ERRORS\segment_6
# Moved sub-010150_C-D.csv to H:\CSIC\ERRORS\segment_6
# Moved sub-010150_D-A.csv to H:\CSIC\ERRORS\segment_6
# Moved sub-010150_D-B.csv to H:\CSIC\ERRORS\segment_6
# Moved sub-010150_D-C.csv to H:\CSIC\ERRORS\segment_6
# Moved sub-010150_A-B.csv to H:\CSIC\ERRORS\segment_7
# Moved sub-010150_A-C.csv to H:\CSIC\ERRORS\segment_7
# Moved sub-010150_A-D.csv to H:\CSIC\ERRORS\segment_7
# Moved sub-010150_B-A.csv to H:\CSIC\ERRORS\segment_7
# Moved sub-010150_B-C.csv to H:\CSIC\ERRORS\segment_7
# Moved sub-010150_B-D.csv to H:\CSIC\ERRORS\segment_7
# Moved sub-010150_C-A.csv to H:\CSIC\ERRORS\segment_7
# Moved sub-010150_C-B.csv to H:\CSIC\ERRORS\segment_7
# Moved sub-010150_C-D.csv to H:\CSIC\ERRORS\segment_7
# Moved sub-010150_D-A.csv to H:\CSIC\ERRORS\segment_7
# Moved sub-010150_D-B.csv to H:\CSIC\ERRORS\segment_7
# Moved sub-010150_D-C.csv to H:\CSIC\ERRORS\segment_7
# Moved sub-010150_A-B.csv to H:\CSIC\ERRORS\segment_8
# Moved sub-010150_A-C.csv to H:\CSIC\ERRORS\segment_8
# Moved sub-010150_A-D.csv to H:\CSIC\ERRORS\segment_8
# Moved sub-010150_B-A.csv to H:\CSIC\ERRORS\segment_8
# Moved sub-010150_B-C.csv to H:\CSIC\ERRORS\segment_8
# Moved sub-010150_B-D.csv to H:\CSIC\ERRORS\segment_8
# Moved sub-010150_C-A.csv to H:\CSIC\ERRORS\segment_8
# Moved sub-010150_C-B.csv to H:\CSIC\ERRORS\segment_8
# Moved sub-010150_C-D.csv to H:\CSIC\ERRORS\segment_8
# Moved sub-010150_D-A.csv to H:\CSIC\ERRORS\segment_8
# Moved sub-010150_D-B.csv to H:\CSIC\ERRORS\segment_8
# Moved sub-010150_D-C.csv to H:\CSIC\ERRORS\segment_8
# Moved sub-010150_A-B.csv to H:\CSIC\ERRORS\segment_9
# Moved sub-010150_A-C.csv to H:\CSIC\ERRORS\segment_9
# Moved sub-010150_A-D.csv to H:\CSIC\ERRORS\segment_9
# Moved sub-010150_B-A.csv to H:\CSIC\ERRORS\segment_9
# Moved sub-010150_B-C.csv to H:\CSIC\ERRORS\segment_9
# Moved sub-010150_B-D.csv to H:\CSIC\ERRORS\segment_9
# Moved sub-010150_C-A.csv to H:\CSIC\ERRORS\segment_9
# Moved sub-010150_C-B.csv to H:\CSIC\ERRORS\segment_9
# Moved sub-010150_C-D.csv to H:\CSIC\ERRORS\segment_9
# Moved sub-010150_D-A.csv to H:\CSIC\ERRORS\segment_9
# Moved sub-010150_D-B.csv to H:\CSIC\ERRORS\segment_9
# Moved sub-010150_D-C.csv to H:\CSIC\ERRORS\segment_9
# Moved sub-010150_A-B.csv to H:\CSIC\ERRORS\segment_10
# Moved sub-010150_A-C.csv to H:\CSIC\ERRORS\segment_10
# Moved sub-010150_A-D.csv to H:\CSIC\ERRORS\segment_10
# Moved sub-010150_B-A.csv to H:\CSIC\ERRORS\segment_10
# Moved sub-010150_B-C.csv to H:\CSIC\ERRORS\segment_10
# Moved sub-010150_B-D.csv to H:\CSIC\ERRORS\segment_10
# Moved sub-010150_C-A.csv to H:\CSIC\ERRORS\segment_10
# Moved sub-010150_C-B.csv to H:\CSIC\ERRORS\segment_10
# Moved sub-010150_C-D.csv to H:\CSIC\ERRORS\segment_10
# Moved sub-010150_D-A.csv to H:\CSIC\ERRORS\segment_10
# Moved sub-010150_D-B.csv to H:\CSIC\ERRORS\segment_10
# Moved sub-010150_D-C.csv to H:\CSIC\ERRORS\segment_10
# Moved sub-010150_A-B.csv to H:\CSIC\ERRORS\segment_11
# Moved sub-010150_A-C.csv to H:\CSIC\ERRORS\segment_11
# Moved sub-010150_A-D.csv to H:\CSIC\ERRORS\segment_11
# Moved sub-010150_B-A.csv to H:\CSIC\ERRORS\segment_11
# Moved sub-010150_B-C.csv to H:\CSIC\ERRORS\segment_11
# Moved sub-010150_B-D.csv to H:\CSIC\ERRORS\segment_11
# Moved sub-010150_C-A.csv to H:\CSIC\ERRORS\segment_11
# Moved sub-010150_C-B.csv to H:\CSIC\ERRORS\segment_11
# Moved sub-010150_C-D.csv to H:\CSIC\ERRORS\segment_11
# Moved sub-010150_D-A.csv to H:\CSIC\ERRORS\segment_11
# Moved sub-010150_D-B.csv to H:\CSIC\ERRORS\segment_11
# Moved sub-010150_D-C.csv to H:\CSIC\ERRORS\segment_11
# Moved sub-010150_A-B.csv to H:\CSIC\ERRORS\segment_12
# Moved sub-010150_A-C.csv to H:\CSIC\ERRORS\segment_12
# Moved sub-010150_A-D.csv to H:\CSIC\ERRORS\segment_12
# Moved sub-010150_B-A.csv to H:\CSIC\ERRORS\segment_12
# Moved sub-010150_B-C.csv to H:\CSIC\ERRORS\segment_12
# Moved sub-010150_B-D.csv to H:\CSIC\ERRORS\segment_12
# Moved sub-010150_C-A.csv to H:\CSIC\ERRORS\segment_12
# Moved sub-010150_C-B.csv to H:\CSIC\ERRORS\segment_12
# Moved sub-010150_C-D.csv to H:\CSIC\ERRORS\segment_12
# Moved sub-010150_D-A.csv to H:\CSIC\ERRORS\segment_12
# Moved sub-010150_D-B.csv to H:\CSIC\ERRORS\segment_12
# Moved sub-010150_D-C.csv to H:\CSIC\ERRORS\segment_12
# Moved sub-010150_A-B.csv to H:\CSIC\ERRORS\segment_13
# Moved sub-010150_A-C.csv to H:\CSIC\ERRORS\segment_13
# Moved sub-010150_A-D.csv to H:\CSIC\ERRORS\segment_13
# Moved sub-010150_B-A.csv to H:\CSIC\ERRORS\segment_13
# Moved sub-010150_B-C.csv to H:\CSIC\ERRORS\segment_13
# Moved sub-010150_B-D.csv to H:\CSIC\ERRORS\segment_13
# Moved sub-010150_C-A.csv to H:\CSIC\ERRORS\segment_13
# Moved sub-010150_C-B.csv to H:\CSIC\ERRORS\segment_13
# Moved sub-010150_C-D.csv to H:\CSIC\ERRORS\segment_13
# Moved sub-010150_D-A.csv to H:\CSIC\ERRORS\segment_13
# Moved sub-010150_D-B.csv to H:\CSIC\ERRORS\segment_13
# Moved sub-010150_D-C.csv to H:\CSIC\ERRORS\segment_13
# Moved sub-010150_A-B.csv to H:\CSIC\ERRORS\segment_14
# Moved sub-010150_A-C.csv to H:\CSIC\ERRORS\segment_14
# Moved sub-010150_A-D.csv to H:\CSIC\ERRORS\segment_14
# Moved sub-010150_B-A.csv to H:\CSIC\ERRORS\segment_14
# Moved sub-010150_B-C.csv to H:\CSIC\ERRORS\segment_14
# Moved sub-010150_B-D.csv to H:\CSIC\ERRORS\segment_14
# Moved sub-010150_C-A.csv to H:\CSIC\ERRORS\segment_14
# Moved sub-010150_C-B.csv to H:\CSIC\ERRORS\segment_14
# Moved sub-010150_C-D.csv to H:\CSIC\ERRORS\segment_14
# Moved sub-010150_D-A.csv to H:\CSIC\ERRORS\segment_14
# Moved sub-010150_D-B.csv to H:\CSIC\ERRORS\segment_14
# Moved sub-010150_D-C.csv to H:\CSIC\ERRORS\segment_14
# Moved sub-010150_A-B.csv to H:\CSIC\ERRORS\segment_15
# Moved sub-010150_A-C.csv to H:\CSIC\ERRORS\segment_15
# Moved sub-010150_A-D.csv to H:\CSIC\ERRORS\segment_15
# Moved sub-010150_B-A.csv to H:\CSIC\ERRORS\segment_15
# Moved sub-010150_B-C.csv to H:\CSIC\ERRORS\segment_15
# Moved sub-010150_B-D.csv to H:\CSIC\ERRORS\segment_15
# Moved sub-010150_C-A.csv to H:\CSIC\ERRORS\segment_15
# Moved sub-010150_C-B.csv to H:\CSIC\ERRORS\segment_15
# Moved sub-010150_C-D.csv to H:\CSIC\ERRORS\segment_15
# Moved sub-010150_D-A.csv to H:\CSIC\ERRORS\segment_15
# Moved sub-010150_D-B.csv to H:\CSIC\ERRORS\segment_15
# Moved sub-010150_D-C.csv to H:\CSIC\ERRORS\segment_15
# Moved sub-010150_A-B.csv to H:\CSIC\ERRORS\segment_16
# Moved sub-010150_A-C.csv to H:\CSIC\ERRORS\segment_16
# Moved sub-010150_A-D.csv to H:\CSIC\ERRORS\segment_16
# Moved sub-010150_B-A.csv to H:\CSIC\ERRORS\segment_16
# Moved sub-010150_B-C.csv to H:\CSIC\ERRORS\segment_16
# Moved sub-010150_B-D.csv to H:\CSIC\ERRORS\segment_16
# Moved sub-010150_C-A.csv to H:\CSIC\ERRORS\segment_16
# Moved sub-010150_C-B.csv to H:\CSIC\ERRORS\segment_16
# Moved sub-010150_C-D.csv to H:\CSIC\ERRORS\segment_16
# Moved sub-010150_D-A.csv to H:\CSIC\ERRORS\segment_16
# Moved sub-010150_D-B.csv to H:\CSIC\ERRORS\segment_16
# Moved sub-010150_D-C.csv to H:\CSIC\ERRORS\segment_16

# %%
# ERRORES LORETA
# SEGMENT 1
# TProgressBar property out of range: archivo vacío

# 29: no tiene C
    # A-C
    # B-C
    # C-A, C-B, C-D
    # D-C

# 45 
    # C-D

# 47 
    # C-D

# 67: no tiene D
    # A-D
    # B-D
    # C-D
    # D-A, D-B, D-C

# 100: no tiene C
    # A-C
    # B-C
    # C-A, C-B, C-D
    # D-C

# 126: no tiene C
    # A-C
    # B-C
    # C-A, C-B, C-D
    # D-C

# 150
    # B-C
    # C-B, C-D
    # D-C

# 163: no tiene A
    # A-B, A-C, A-D
    # B-A, B-C
    # C-A, C-B,
    # D-A

# 170
    # B-A
    # C-A

# 196: no tiene A
    # A-B, A-C, A-D
    # B-A
    # C-A
    # D-A

# 200
    # B-A

# 204: solo tiene D y C intercalados
    # A-B, A-C, A-D
    # B-A, B-C, B-D
    # C-A, C-B
    # D-A, D-B

# 239: solo tiene D y C intercalados
    # A-B, A-C, A-D
    # B-A, B-C, B-D
    # C-A, C-B
    # D-A, D-B

# 270: no tiene C
    # A-C
    # B-C
    # C-A, C-B, C-D
    # D-C

# 277: no tiene C
    # A-C
    # B-C
    # C-A, C-B, C-D
    # D-C

# 285: ninguno por eventos (no se puede arreglar porque no tiene eventos)

# 286
    # A-D
    # C-D
    # D-A, D-C

# 291
    # C-D

# 296
    # B-C
    # C-D

# 300: no tiene D
    # A-D
    # B-D
    # C-D
    # D-A, D-B, D-C

# 301
    # C-B

# 305
    # B-C
    # C-D
    # D-B, D-C
